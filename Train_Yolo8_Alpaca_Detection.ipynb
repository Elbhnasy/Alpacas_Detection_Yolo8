# %%
# Connect with drive Data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# save root dir path
ROOT_DIR = '/content/drive/MyDrive/Object_Detection/Alpaca_Detection_project'

# %%
# checking Access for GPU
# !nvidia-smi
# Out:
# Tue Aug 22 19:25:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Installing YOLO
# !pip install ultralytics

from IPython import display
display.clear_output()

# %%
# Check ultralystics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.159 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# Custom Training
import os
from ultralytics import YOLO

# build a new model from YAML
model = YOLO('yolov8m.yaml')

# Get data dir
data_path = os.path.join(ROOT_DIR,'colab_config.yaml')

# Use Model in train
results = model.train(data=data_path , epochs=50, imgsz=800, plots=True)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
# ...

# %%
import shutil

source_path = '/content/runs/runs1'

shutil.move( source_path,ROOT_DIR)
# Out:
# '/content/drive/MyDrive/Object_Detection/Alpaca_Detection_project'
